# %%
import sys

sys.path.append("../src")

import dataset.data_loader as dl

print(dl.__file__)
# Out:
# c:\Users\LENOVO\OneDrive\Desktop\GeoRestore AI\GeoRestore-AI\notebooks\../src\dataset\data_loader.py

# %%
import sys

sys.path.append("../src")

import dataset.data_loader as dl

print(dir(dl))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__']

# %%
import sys

sys.path.append("../src")

from dataset.data_loader import RiceDataset

print("Import Successful!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 5
#       1 import sys
#       3 sys.path.append("../src")
# ----> 5 from dataset.data_loader import RiceDataset
#       7 print("Import Successful!")
#
# ImportError: cannot import name 'RiceDataset' from 'dataset.data_loader' (c:\Users\LENOVO\OneDrive\Desktop\GeoRestore AI\GeoRestore-AI\notebooks\../src\dataset\data_loader.py)

# %%
import sys
import os

sys.path.append("../src")

from dataset.data_loader import RiceDataset

dataset = RiceDataset("../data/raw/RICE1")

print("Total Image Pairs:", len(dataset))

cloud_path, label_path = dataset.get_pair(0)

print("\nCloud Image:")
print(cloud_path)

print("\nGround Truth:")
print(label_path)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 6
#       2 import os
#       4 sys.path.append("../src")
# ----> 6 from dataset.data_loader import RiceDataset
#       8 dataset = RiceDataset("../data/raw/RICE1")
#      10 print("Total Image Pairs:", len(dataset))
#
# ImportError: cannot import name 'RiceDataset' from 'dataset.data_loader' (c:\Users\LENOVO\OneDrive\Desktop\GeoRestore AI\GeoRestore-AI\notebooks\../src\dataset\data_loader.py)

# %%
import sys

sys.path.append("../src")

import dataset.data_loader as dl

print(open(dl.__file__, "r").read())
